# %% [markdown]
# # 函数input()的工作原理

# %%
message = input("Tell me something, and I will repeat it back to you: ")
print(message)
# Out:
# Tell me something, and I will repeat it back to you: easymoneysniper
# easymoneysniper

# %%
name = input("Please enter your name: ")
print("Hello, " + name + "!")
# Out:
# Please enter your name: Ding
# Hello, Ding!

# %%
prompt = "If you tell us who you are, we can personalize the messages you see."
prompt += "\nWhat is your first name?"

name = input(prompt)
print("\nHello, " + name + "!")
# Out:
# If you tell us who you are, we can personalize the messages you see.
# What is your first name?Ding
#
# Hello, Ding!

# %%
age = input("How old are you?")
age                                # Python将用户输入解读为字符串
age >= 18
# Out:
# How old are you?21
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-74e57a0d03e8> in <module>
#       1 age = input("How old are you?")
#       2 age                                # Python将用户输入解读为字符串
# ----> 3 age >= 18
#
# TypeError: '>=' not supported between instances of 'str' and 'int'

# %%
age = input("How old are you?")
age = int(age)                               
age >= 18
# Out:
# How old are you?21
# True

# %%
height = input("How tall are you, in inches? ")
height = int(height)

if height >= 36:
    print("\nYou're tall enough to ride!")
else:
    print("\nYou'll be able to ride when you're a little older!")
# Out:
# How tall are you, in inches? 71
#
# You're tall enough to ride!

# %%
5 % 3
# Out:
# 2

# %%
number = input("Enter a number, and I'll tell you if it's even or odd:")
number = int(number)

if number % 2 == 0:
    print("\nThe number " + str(number) + " is even.") # number的类型需要转换回字符串类型
else:
    print("\nThe number " + str(number) + " is old.")
# Out:
# Enter a number, and I'll tell you if it's even or odd:7
#
# The number 7 is old.

# %% [markdown]
# # while循环简介

# %%
current_number = 1
while current_number <= 5:
    print(current_number)
    current_number += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
prompt = "\nTell me something, and I will repeat back to you:"
prompt += "\nEnter 'quit' to end the program."
message = ''
while message != 'quit':
    message = input(prompt)
    print(message)
# Out:
# Tell me something, and I will repeat back to you:
# Enter 'quit' to end the program.KD
# KD
#
# Tell me something, and I will repeat back to you:
# Enter 'quit' to end the program.Chris Brown
# Chris Brown
#
# Tell me something, and I will repeat back to you:
# Enter 'quit' to end the program.quit
# quit

# %%
prompt = "\nTell me something, and I will repeat back to you:"
prompt += "\nEnter 'quit' to end the program."
message = ''
while message != 'quit':
    message = input(prompt)
    
    if message != 'quit':
        print(message)
# Out:
# Tell me something, and I will repeat back to you:
# Enter 'quit' to end the program.Hello everyone!
# Hello everyone!
#
# Tell me something, and I will repeat back to you:
# Enter 'quit' to end the program.Hello again.
# Hello again.
#
# Tell me something, and I will repeat back to you:
# Enter 'quit' to end the program.quit

# %%
prompt = "\nTell me something, and I will repeat back to you:"
prompt += "\nEnter 'quit' to end the program."

active = True   # 标志很有用
while active:
    message = input(prompt)
    
    if message != 'quit':
        active = False
    else:
        print(message)

# %%
prompt = "\nPlease enter the name of a city you have visited:"
prompt += "\nEnter 'quit' when you are finished."

while True:
    city = input(prompt)
    
    if city == 'quit':
        break
    else:
        print("I'd love to go to " + city.title() + "!")
# Out:
# Please enter the name of a city you have visited:
# Enter 'quit' when you are finished.New York
# I'd love to go to New York!
#
# Please enter the name of a city you have visited:
# Enter 'quit' when you are finished.San Francisco
# I'd love to go to San Francisco!
#
# Please enter the name of a city you have visited:
# Enter 'quit' when you are finished.quit

# %%
current_number = 0
while current_number < 10:
    current_number += 1
    if current_number % 2 == 0:
        continue                  # 忽略余下代码，并返回至循环的开头
        
    print(current_number)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
 x = 1
while x <= 5:
    print(x)
    x += 1   # 避免无限循环
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# # 3 使用while循环来处理列表和字典

# %%
# 首先，创建一个待验证用户列表
#  和一个用于储存已验证用户的空列表
unconfirmed_users = ['alice', 'brian', 'candace']
confirmed_users = []

# 验证每个用户，直到没有未验证用户为止
# 将每个经过验证的列表都移动到已验证用户列表中
while unconfirmed_users:
    current_user = unconfirmed_users.pop()  #pop()以每次一个的方式从列表末尾删除元素,并可以赋值
    
    print("Verifying user: " + current_user.title())
    confirmed_users.append(current_user)
    
# 显示所有已验证的用户
print("\nThe following users have been confirmed:")
for confirmed_user in confirmed_users:
    print(confirmed_user.title())
# Out:
# Verifying user: Candace
# Verifying user: Brian
# Verifying user: Alice
#
# The following users have been confirmed:
# Candace
# Brian
# Alice

# %%
pets = ['dog', 'cat', 'dog', 'goldfish', 'cat', 'rabbit', 'cat']
print(pets)

while 'cat' in pets:           # 判断'cat' in pets的True or False !!!
    pets.remove('cat')         # remove经典
    
print(pets)
# Out:
# ['dog', 'cat', 'dog', 'goldfish', 'cat', 'rabbit', 'cat']
# ['dog', 'dog', 'goldfish', 'rabbit']

# %%
 responses = {}

# 设置一个标志， 指出调查是否继续
polling_active = True

while polling_active:
    # 提示输入被调查者的名字和回答
    name = input("\nWhat is your name?")
    response = input("Which mountain would you like to climb someday? ")
    
    # 将答卷储存在字典中
    responses[name] = response
    
    # 看看是否还有人要参与调查
    repeat = input("Would you like to let another person respond?(yes/ no) ")
    if repeat == 'no':
        polling_active = False

# 调查结束， 显示结果
print("\n--- Poll Results ---")
for name, response in responses.items():
    print(name + " would like to climb " + response + ".")
# Out:
# What is your name?Eric
# Which mountain would you like to climb someday? Denali
# Would you like to let another person respond?(yes/ no) yes
#
# What is your name?Lynn
# Which mountain would you like to climb someday? Devil's Thumb
# Would you like to let another person respond?(yes/ no) no
#
# --- Poll Results ---
# Eric would like to climb Denali.
# Lynn would like to climb Devil's Thumb.

# %% [markdown]
# # 动手试一试

# %% [markdown]
# ## 7-1

# %%
prompt = "What kind of car would you like to rent?"
prompt += "\nLet me see if I can find you a "

car = input(prompt)
# Out:
# What kind of car would you like to rent?
# Let me see if I can find you a Tesla

# %% [markdown]
# ## 7-2

# %%
number = input("How many people are for dinner, please? ")
number = int(number)

if number > 8:
    print("There are not any free tables.")
else:
    print("There have available tables.")
# Out:
# How many people are for dinner, please? 6
# There have available tables.

# %% [markdown]
# ## 7-3

# %%
number = input("Enter a number, and I'll tell you if it is a multiple of ten")
number = int(number)

if number % 10 == 0:
    print("\nThe number " + str(number) + " is a multiple of ten.")
else:
    print("\nThe number " + str(number) + " is not a multiple of ten.")
# Out:
# Enter a number, and I'll tell you if it is a multiple of ten90
#
# The number 90 is a multiple of ten.

# %% [markdown]
# ## 7-4

# %%
prompt = "\nPlease enter the toppings you want:"
prompt += "\n(Enter 'quit' when you are finished.)"

while True:
    pizza = input(prompt)
    
    if pizza == 'quit': 
        break
    else:
        print("We're going to add this to our pizza.")
# Out:
# Please enter the toppings you want:
# (Enter 'quit' when you are finished.)extra cheese
# We're going to add this to our pizza.
#
# Please enter the toppings you want:
# (Enter 'quit' when you are finished.)mushrooms
# We're going to add this to our pizza.
#
# Please enter the toppings you want:
# (Enter 'quit' when you are finished.)quit

# %% [markdown]
# ## 7-5

# %%
flag = True
while flag:
    message = input("Plese tell me your age!\n")
    if message == 'none':
        flag = False
    else:
        age =int(message)
        if age <= 3:
            print("The ticket is free.")
        elif age <= 12:
            print("The ticket is $10.")
        else:
            print("The ticket is $15.")

# %% [markdown]
# ## 7-6

# %%
active = True                  # √用active来控制循环结束的时机
while active:
    message = input("Plese tell me your age!\n")
    if message == 'quit':      # √使用条件语句结束循环
        break                  # √使用break语句结束循环
    else:
        age =int(message)
        if age <= 3:
            print("The ticket is free.")
        elif age <= 12:
            print("The ticket is $10.")
        else:
            print("The ticket is $15.")
# Out:
# Plese tell me your age!
# 1
# The ticket is free.
# Plese tell me your age!
# quit

# %% [markdown]
# ## 7-7

# %%
while True:
    print("你是真滴帅！")
# Out:
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# 你是真滴帅！
# ...

# %% [markdown]
# ## 7-8

# %%
sandwich_orders = ['tuna', 'beef', 'cheese']
finished_sandwiches = []

while sandwich_orders:
    finished_sandwich = sandwich_orders.pop()
    print("I made your " + finished_sandwich + " sandwich.")
    finished_sandwiches.append(finished_sandwich)
    
print("\nAll the sandwiches are ready.")
for sandwich in finished_sandwiches:
    print("\n" + sandwich.title() + " Sandwich")
# Out:
# I made your cheese sandwich.
# I made your beef sandwich.
# I made your tuna sandwich.
#
# All the sandwiches are ready.
#
# Cheese Sandwich
#
# Beef Sandwich
#
# Tuna Sandwich

# %% [markdown]
# ## 7-9

# %%
sandwich_orders = ['tuna', 'pastrami', 'beef', 'pastrami' 'cheese', 'pastrami']
finished_sandwiches = []

# pastrami已经卖完了，将其从菜单中删除
print("The pastrami sandwiches are sold out.")

while 'pastrami' in sandwich_orders:
    sandwich_orders.remove('pastrami')
print(sandwich_orders)
finished_sandwiches = []

# 点单
while sandwich_orders:
    finished_sandwich = sandwich_orders.pop()
    print("I made your " + finished_sandwich + " sandwich.")
    finished_sandwiches.append(finished_sandwich)
    
print("\nAll the sandwiches are ready.")
for sandwich in finished_sandwiches:
    print("\n" + sandwich.title() + " Sandwich")
# Out:
# The pastrami sandwiches are sold out.
# ['tuna', 'beef', 'pastramicheese']
# I made your pastramicheese sandwich.
# I made your beef sandwich.
# I made your tuna sandwich.
#
# All the sandwiches are ready.
#
# Pastramicheese Sandwich
#
# Beef Sandwich
#
# Tuna Sandwich

# %% [markdown]
# ## 7-10

# %%
results = {}

active = True

while active:
    name = input("What's your name?")
    place = input("If you could visit one place in the world, where would you go? ")
    
    results[name] = place
    
    repeat = input("Would you like to let another person respond? (yes/ no) ")
    if repeat == "no":
        active = False

print("\n--- Poll Results ---")
for name, place in results.items():
    print(name + " would like to visit " + place + ".")
# Out:
# What's your name?Ding
# If you could visit one place in the world, where would you go? Chengdu
# Would you like to let another person respond? (yes/ no) yes
# What's your name?Gao
# If you could visit one place in the world, where would you go? Jinan
# Would you like to let another person respond? (yes/ no) no
#
# --- Poll Results ---
# Ding would like to visit Chengdu.
# Gao would like to visit Jinan.
